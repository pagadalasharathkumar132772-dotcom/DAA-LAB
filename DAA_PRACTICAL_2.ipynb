# %% [markdown]
# <a href="https://colab.research.google.com/github/pagadalasharathkumar132772-dotcom/DAA-LAB/blob/main/DAA_PRACTICAL_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Linear Search
import time

# Input from the user
n = int(input("Enter the number of elements: "))

arr = []
print(f"Enter {n} sorted elements:")
for i in range(n):
    arr.append(int(input()))

# Element to search
key = int(input("Enter the element to search: "))

# Start timer
start_time = time.time()

# Linear Search
position = -1
for i in range(n):
    if arr[i] == key:
        position = i
        break

# Stop timer
end_time = time.time()

# Calculate execution time
execution_time = end_time - start_time

# Display result
if position != -1:
    print(f"\nElement {key} found at index {position}")
else:
    print(f"\nElement {key} not found")

# Display execution time
print(f"\nExecution Time: {execution_time:.6f} seconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(1)")
print("Average Case : O(n)")
print("Worst Case   : O(n)")
print("Space Complexity: O(1)")



# Binary Search


# Input from the user
n = int(input("Enter the number of elements: "))

arr = []
print(f"Enter {n} sorted elements:")
for i in range(n):
    arr.append(int(input()))

# Element to search
key = int(input("Enter the element to search: "))

# Start timer
start_time = time.time()

# Binary Search
low = 0
high = n - 1
position = -1

while low <= high:
    mid = (low + high) // 2

    if arr[mid] == key:
        position = mid
        break
    elif arr[mid] < key:
        low = mid + 1
    else:
        high = mid - 1

# Stop timer
end_time = time.time()

# Calculate execution time
execution_time = end_time - start_time

# Display result
if position != -1:
    print(f"\nElement {key} found at index {position}")
else:
    print(f"\nElement {key} not found")

# Display execution time
print(f"\nExecution Time: {execution_time:.6f} seconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(1)")
print("Average Case : O(log n)")
print("Worst Case   : O(log n)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 5
# Enter 5 sorted elements:
# 5
# 6
# 5
# 8
# 9
# Enter the element to search: 6
#
# Element 6 found at index 1
#
# Execution Time: 0.000177 seconds
#
# Time Complexity:
# Best Case    : O(1)
# Average Case : O(n)
# Worst Case   : O(n)
# Space Complexity: O(1)
# Enter the number of elements: 5
# Enter 5 sorted elements:
# 9
# 8
# 5
# 2
# 6
# Enter the element to search: 2
#
# Element 2 not found
#
# Execution Time: 0.000432 seconds
#
# Time Complexity:
# Best Case    : O(1)
# Average Case : O(log n)
# Worst Case   : O(log n)
# Space Complexity: O(1)
